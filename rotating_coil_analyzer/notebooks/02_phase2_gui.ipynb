# %% [markdown]
# # 02 — Phase II GUI (analysis tab)
#
# This notebook launches a **combined GUI**:
# - **Phase I tab:** browse catalog, load a segment, preview/diagnostics
# - **Phase II tab:** run turn-QC, per-turn FFT (per FDI channel), plots, Normal/Skew bars
#
# **Contract:** No synthetic time. Analysis uses turn/sample indexing and an angular grid.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

import ipywidgets as w
import matplotlib.pyplot as plt
w.Widget.close_all()
plt.close("all")

# %% [markdown]
# ## Launch the combined GUI
#
# Use the Phase I tab to load a segment, then switch to Phase II tab and click **Compute FFT (per turn)**.

# %%
from rotating_coil_analyzer.gui.app import build_gui
build_gui()
# Out:
# Tab(children=(VBox(children=(HBox(children=(Text(value='', description='Folder', layout=Layout(width='78%'), p…
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\gui\phase3_kn.py:448, in build_phase3_kn_panel.<locals>._on_load_kn(_btn)
#     439     return
#     441 head = compute_head_kn_from_csv(
#     442     p,
#     443     warm_geometry=bool(head_warm.value),
#    (...)
#     446     strict_header=bool(head_strict_header.value),
#     447 )
# --> 448 seg_kn = compute_segment_kn_from_head(
#     449     head,
#     450     abs_connection=head_abs_conn.value.strip(),
#     451     cmp_connection=head_cmp_conn.value.strip(),
#     452     ext_connection=head_ext_conn.value.strip() if head_ext_conn.value.strip() else None,
#     453     source_label=f"head_csv:{p}",
#     454 )
#     455 st.kn = seg_kn
#     456 st.kn_path = f"head_csv:{p}"
#
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\analysis\kn_head.py:366, in compute_segment_kn_from_head(head, abs_connection, cmp_connection, ext_connection, source_label)
#     363         acc = acc + complex(coef) * head.kn_by_index[idx]
#     364     return acc
# --> 366 kn_abs = combine(abs_connection)
#     367 kn_cmp = combine(cmp_connection)
#     368 kn_ext = None
#
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\analysis\kn_head.py:362, in compute_segment_kn_from_head.<locals>.combine(conn)
#     360 for coef, idx in terms:
#     361     if idx not in head.kn_by_index:
# --> 362         raise KeyError(f"Coil {idx[0]}.{idx[1]} not found in head CSV")
#     363     acc = acc + complex(coef) * head.kn_by_index[idx]
#     364 return acc
#
# KeyError: 'Coil 1.1 not found in head CSV'
