# %% [markdown]
# # 02 — Phase II GUI (analysis tab)
#
# This notebook launches a **combined GUI**:
# - **Phase I tab:** browse catalog, load a segment, preview/diagnostics
# - **Phase II tab:** run turn-QC, per-turn FFT (per FDI channel), plots, Normal/Skew bars
#
# **Contract:** No synthetic time. Analysis uses turn/sample indexing and an angular grid.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

import ipywidgets as w
import matplotlib.pyplot as plt
w.Widget.close_all()
plt.close("all")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Launch the combined GUI
#
# Use the Phase I tab to load a segment, then switch to Phase II tab and click **Compute FFT (per turn)**.

# %%
from rotating_coil_analyzer.gui.app import build_gui
build_gui()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from rotating_coil_analyzer.gui.app import build_gui
#       2 build_gui()
#
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\gui\app.py:15
#      13 from rotating_coil_analyzer.ingest.readers_sm18 import Sm18CorrSigsReader, Sm18ReaderConfig
#      14 from rotating_coil_analyzer.ingest.readers_mba import MbaRawMeasurementReader, MbaReaderConfig
# ---> 15 from rotating_coil_analyzer.models.catalog import Catalog
#      16 from rotating_coil_analyzer.models.frames import SegmentFrame
#      18 from rotating_coil_analyzer.gui.phase2 import build_phase2_panel
#
# ImportError: cannot import name 'Catalog' from 'rotating_coil_analyzer.models.catalog' (C:\Users\albellel\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\models\catalog.py)
