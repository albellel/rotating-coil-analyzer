# %% [markdown]
# # 02 — Phase II GUI (analysis tab)
#
# This notebook launches a **combined GUI**:
# - **Phase I tab:** browse catalog, load a segment, preview/diagnostics
# - **Phase II tab:** run turn-QC, per-turn FFT (per FDI channel), plots, Normal/Skew bars
#
# **Contract:** No synthetic time. Analysis uses turn/sample indexing and an angular grid.

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

import ipywidgets as w
import matplotlib.pyplot as plt
w.Widget.close_all()
plt.close("all")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Launch the combined GUI
#
# Use the Phase I tab to load a segment, then switch to Phase II tab and click **Compute FFT (per turn)**.

# %%
from rotating_coil_analyzer.gui.app import build_gui
build_gui()
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from rotating_coil_analyzer.gui.app import build_gui
# ----> 2 build_gui()
#
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\gui\app.py:482, in build_gui(clear_cell_output)
#     475 shared: Dict[str, Any] = {
#     476     "catalog": None,
#     477     "segment_frame": None,
#     478     "segment_path": None,
#     479 }
#     481 phase1 = _build_phase1_panel(shared)
# --> 482 phase2 = build_phase2_panel(lambda: shared.get("segment_frame"))
#     483 phase3 = build_phase3_kn_panel(lambda: shared.get("segment_frame"), lambda: shared.get("segment_path"))
#     484 def _get_segmeta():
#     485     # Keep metadata minimal and stable: primarily the source path for display.
#
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\gui\phase2.py:1181, in build_phase2_panel(get_segmentframe_callable, default_n_max)
#    1178 btn_save_table.on_click(_save_table)
#    1179 btn_show_head.on_click(_show_head)
# -> 1181 _init_plot_once()
#    1183 # ---------------------------
#    1184 # Layout: two columns
#    1185 # ---------------------------
#    1186 compute_box = w.VBox(
#    1187     [
#    1188         w.HTML("<b>Step 1 — Preview and apply data-quality cuts</b>"),
#    (...)
#    1198     layout=w.Layout(border="1px solid #ddd", padding="10px", width="100%"),
#    1199 )
#
# File ~\python-projects\rotating-coil-analyzer\rotating_coil_analyzer\gui\phase2.py:462, in build_phase2_panel.<locals>._init_plot_once()
#     459         plt.ion()
#     461 state.fig, state.ax = fig, ax
# --> 462 plot_slot.children = (fig.canvas,)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:690, in TraitType.set(self, obj, value)
#     689 def set(self, obj: HasTraits, value: S) -> None:
# --> 690     new_value = self._validate(obj, value)
#     691     assert self.name is not None
#     692     try:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:722, in TraitType._validate(self, obj, value)
#     720     return value
#     721 if hasattr(self, "validate"):
# --> 722     value = self.validate(obj, value)
#     723 if obj._cross_validation_lock is False:
#     724     value = self._cross_validate(obj, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:3482, in Container.validate(self, obj, value)
#    3479 if value is None:
#    3480     return value
# -> 3482 value = self.validate_elements(obj, value)
#    3484 return t.cast(T, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:3494, in Container.validate_elements(self, obj, value)
#    3492     v = self._trait._validate(obj, v)
#    3493 except TraitError as error:
# -> 3494     self.error(obj, v, error)
#    3495 else:
#    3496     validated.append(v)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:810, in TraitType.error(self, obj, value, error, info)
#     801         else:
#     802             error.args = (
#     803                 "The '{}' trait contains {} which " "expected {}, not {}.".format(
#     804                     self.name,
#    (...)
#     808                 ),
#     809             )
# --> 810     raise error
#     812 # this trait caused an error
#     813 if self.name is None:
#     814     # this is not the root trait
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:3492, in Container.validate_elements(self, obj, value)
#    3490 for v in value:
#    3491     try:
# -> 3492         v = self._trait._validate(obj, v)
#    3493     except TraitError as error:
#    3494         self.error(obj, v, error)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:722, in TraitType._validate(self, obj, value)
#     720     return value
#     721 if hasattr(self, "validate"):
# --> 722     value = self.validate(obj, value)
#     723 if obj._cross_validation_lock is False:
#     724     value = self._cross_validate(obj, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:2311, in Instance.validate(self, obj, value)
#    2309     return t.cast(T, value)
#    2310 else:
# -> 2311     self.error(obj, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:815, in TraitType.error(self, obj, value, error, info)
#     812 # this trait caused an error
#     813 if self.name is None:
#     814     # this is not the root trait
# --> 815     raise TraitError(value, info or self.info(), self)
#     817 # this is the root trait
#     818 if obj is not None:
#
# TraitError: The 'children' trait of a Box instance contains an Instance of a TypedTuple which expected a Widget, not the FigureCanvasAgg at '0x201121708a0'.
